# %%
import numpy as np
import pandas as pd
from sklearn.neighbors import NearestNeighbors
import time
from scipy.stats import rankdata
from hnsw_models import HNSW, HNSW_V2, HNSWNode
from tqdm import tqdm

# %%
# ------------------------ #
#    Helper Functions
# ------------------------ #

def generate_random_embeddings(num_embeddings, dim):
    """Generate random embeddings."""
    return np.random.rand(num_embeddings, dim).astype(np.float32)

def mean_reciprocal_rank(y_true, y_pred):
    """Calculate Mean Reciprocal Rank (MRR)."""
    mrrs = []
    for true_labels, pred_scores in zip(y_true, y_pred):
        ranks = rankdata(-pred_scores, method='ordinal')
        true_rank = ranks[np.argmax(true_labels)]
        mrrs.append(1.0 / true_rank)
    return np.mean(mrrs)

def recall_at_k(actual, predicted, k):
    """Calculate Recall@K."""
    actual_set = set(actual[:k])
    predicted_set = set(predicted[:k])
    return len(actual_set & predicted_set) / len(actual_set)

def precision_at_k(actual, predicted, k):
    """Calculate Precision@K."""
    actual_set = set(actual[:k])
    predicted_set = set(predicted[:k])
    return len(actual_set & predicted_set) / k

def calculate_metrics(exact_labels, hnsw_labels, K):
    """Calculate recall, precision, and MRR."""
    recall_scores = []
    precision_scores = []
    mrr_scores = []

    for i in range(len(exact_labels)):
        recall = recall_at_k(exact_labels[i], hnsw_labels[i], K)
        precision = precision_at_k(exact_labels[i], hnsw_labels[i], K)
        mrr = mean_reciprocal_rank(exact_labels[i], hnsw_labels[i])

        recall_scores.append(recall)
        precision_scores.append(precision)
        mrr_scores.append(mrr)

    average_recall = np.mean(recall_scores)
    average_precision = np.mean(precision_scores)
    average_mrr = np.mean(mrr_scores)

    return average_recall, average_precision, average_mrr


def benchmark_hnsw(hnsw_class, embeddings, test_embeddings, K):
    """Benchmark HNSW or HNSW_V2."""
    hnsw = hnsw_class(max_level=3)

    start_time_hnsw_add = time.time()
    for i, emb in enumerate(embeddings):
        hnsw.add_node(emb, label=f"emb{i}")
    hnsw_add_time = time.time() - start_time_hnsw_add

    hnsw_knn_labels = []
    start_time_hnsw_search = time.time()
    for emb in test_embeddings:
        top_k_nodes = hnsw.search_knn(emb, k=K)
        hnsw_knn_labels.append([int(node.label.replace('emb', '')) for node in top_k_nodes])
    hnsw_search_time = time.time() - start_time_hnsw_search

    return hnsw_knn_labels, hnsw_add_time, hnsw_search_time

# %%
# ------------------------ #
#    Main Function
# ------------------------ #

def run_benchmark(num_embeddings, embedding_dim, K):
    np.random.seed(42)
    
    """Run the full benchmark for HNSW and HNSW_V2."""
    # Generate embeddings and test embeddings
    embeddings = generate_random_embeddings(num_embeddings, embedding_dim)
    test_embeddings = generate_random_embeddings(num_embeddings, embedding_dim)

    # Perform exact KNN using scikit-learn for ground truth
    start_time_knn = time.time()
    knn_model = NearestNeighbors(n_neighbors=K, algorithm='brute', metric='euclidean')
    knn_model.fit(embeddings)
    distances, indices = knn_model.kneighbors(test_embeddings)
    knn_exact_time = time.time() - start_time_knn

    exact_knn_labels = [indices[i] for i in range(len(test_embeddings))]
    exact_knn_distances = [distances[i] for i in range(len(test_embeddings))]

    # Benchmark HNSW (V1)
    hnsw_v1_labels, hnsw_v1_add_time, hnsw_v1_search_time = benchmark_hnsw(HNSW, embeddings, test_embeddings, K)

    # Benchmark HNSW_V2
    hnsw_v2_labels, hnsw_v2_add_time, hnsw_v2_search_time = benchmark_hnsw(HNSW_V2, embeddings, test_embeddings, K)

    # Calculate metrics for HNSW (V1)
    v1_recall, v1_precision, v1_mrr = calculate_metrics(exact_knn_labels, hnsw_v1_labels, K)

    # Calculate metrics for HNSW_V2
    v2_recall, v2_precision, v2_mrr = calculate_metrics(exact_knn_labels, hnsw_v2_labels, K)

    # Store the results in a pandas DataFrame
    benchmark_df = pd.DataFrame({
        'method': ['HNSW_V1', 'HNSW_V2'],
        'num_embeddings': [num_embeddings, num_embeddings],
        'embedding_dim': [embedding_dim, embedding_dim],
        'average_recall': [v1_recall, v2_recall],
        'average_precision': [v1_precision, v2_precision],
        'average_mrr': [v1_mrr, v2_mrr],
        'add_time': [hnsw_v1_add_time, hnsw_v2_add_time],
        'search_time': [hnsw_v1_search_time, hnsw_v2_search_time],
        'knn_exact_search_time': [knn_exact_time, knn_exact_time]
    })

    return benchmark_df

# %%
# ------------------------ #
#    Running the Benchmark
# ------------------------ #
# Parameters
num_embeddings = 1000
embedding_dim = 128
K = 10

# Run the benchmark and display the results
benchmark_results = run_benchmark(num_embeddings, embedding_dim, K)

# %%
benchmark_results
# Out:
#     method  num_embeddings  embedding_dim  average_recall  average_precision  \
# 0  HNSW_V1            1000            128          0.0336             0.0336
# 1  HNSW_V2            1000            128          0.2366             0.2366
#
#    average_mrr  add_time  search_time  knn_exact_search_time
# 0          1.0  0.082868     0.087959               0.039304
# 1          1.0  0.237785     0.566206               0.039304

# %%
benchmark_results
# Out:
#     method  num_embeddings  embedding_dim  average_recall  average_precision  \
# 0  HNSW_V1            1000            128          0.0336             0.0336
# 1  HNSW_V2            1000            128          0.2366             0.2366
#
#    average_mrr  add_time  search_time  knn_exact_search_time
# 0          1.0  0.060096     0.117145               0.077236
# 1          1.0  0.226020     0.546387               0.077236

# %% [markdown]
# # Run Full Benchmark

# %%
# Define the grid search parameters
num_embeddings_values = [int(1e4), int(1e5), int(1e6)]  # Example values for the number of embeddings
embedding_dim_values = [128, 738, 1024]      # Example values for the dimension of embeddings
K_values = [50, 100, 200]

# %%
from tqdm import tqdm

# Initialize an empty DataFrame to store all results
all_benchmark_results = pd.DataFrame()

# Total number of iterations for tqdm
total_iterations = len(num_embeddings_values) * len(embedding_dim_values) * len(K_values)

# Perform grid search with progress tracking
with tqdm(total=total_iterations) as pbar:
    for num_embeddings in num_embeddings_values:
        for embedding_dim in embedding_dim_values:
            for K in K_values:
                # Print the current combination
                # print(f"Iter num_embeddings={num_embeddings}, embedding_dim={embedding_dim}, K={K}")

                # Run the benchmark for the current set of parameters
                benchmark_results = run_benchmark(num_embeddings, embedding_dim, K)

                # Concatenate the results to the main DataFrame
                all_benchmark_results = pd.concat([all_benchmark_results, benchmark_results], ignore_index=True)

                # Update the progress bar
                pbar.update(1)
# Out:
#  48%|████▊     | 13/27 [10:36:08<11:25:04, 2936.02s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 18
#      12 for embedding_dim in embedding_dim_values:
#      13     for K in K_values:
#      14         # Print the current combination
#      15         # print(f"Iter num_embeddings={num_embeddings}, embedding_dim={embedding_dim}, K={K}")
#      16
#      17         # Run the benchmark for the current set of parameters
# ---> 18         benchmark_results = run_benchmark(num_embeddings, embedding_dim, K)
#      20         # Concatenate the results to the main DataFrame
#      21         all_benchmark_results = pd.concat([all_benchmark_results, benchmark_results], ignore_index=True)
#
# Cell In[3], line 24, in run_benchmark(num_embeddings, embedding_dim, K)
#      21 exact_knn_distances = [distances[i] for i in range(len(test_embeddings))]
#      23 # Benchmark HNSW (V1)
# ---> 24 hnsw_v1_labels, hnsw_v1_add_time, hnsw_v1_search_time = benchmark_hnsw(HNSW, embeddings, test_embeddings, K)
#      26 # Benchmark HNSW_V2
#      27 hnsw_v2_labels, hnsw_v2_add_time, hnsw_v2_search_time = benchmark_hnsw(HNSW_V2, embeddings, test_embeddings, K)
#
# Cell In[2], line 58, in benchmark_hnsw(hnsw_class, embeddings, test_embeddings, K)
#      56 start_time_hnsw_add = time.time()
#      57 for i, emb in enumerate(embeddings):
# ---> 58     hnsw.add_node(emb, label=f"emb{i}")
#      59 hnsw_add_time = time.time() - start_time_hnsw_add
#      61 hnsw_knn_labels = []
#
# File ~/Documents/david/pdf-search-llm-rag/hnsw/hnsw_models.py:31, in HNSW.add_node(self, embedding, label)
#      29     self.entry_point = new_node
#      30 else:
# ---> 31     self._insert_node(new_node, level)
#      32 for l in range(level + 1):
#      33     self.layers[l].append(new_node)
#
# File ~/Documents/david/pdf-search-llm-rag/hnsw/hnsw_models.py:48, in HNSW._insert_node(self, new_node, level)
#      46 # list: [level_new_node, level_new_node-1, ..., 0]
#      47 for l in reversed(range(level + 1)):
# ---> 48     current_node = self._search_layer(new_node.embedding, current_node, l)
#      49     self._connect_neighbors(new_node, current_node, l)
#
# File ~/Documents/david/pdf-search-llm-rag/hnsw/hnsw_models.py:57, in HNSW._search_layer(self, query, entry_point, layer)
#      54 neighbors = current_node.neighbors[layer]
#      56 # Return the closest HNSWNode in that layer otherwise None
# ---> 57 closest = self._find_closest(query, neighbors)
#      59 # if in that level there is no neighbor, then break
#      60 # if the distance of the query to the closest neighbor is greater than the distance of the query to the current node, then break
#      61 if closest is None or self._distance(query, closest.embedding) >= self._distance(query, current_node.embedding):
#      62     # If True (Neighbor Not Closer) then break
#
# File ~/Documents/david/pdf-search-llm-rag/hnsw/hnsw_models.py:83, in HNSW._find_closest(self, query, neighbors)
#      81     return None
#      82 neighbor_embeddings = np.array([neighbor.embedding for neighbor in neighbors])
# ---> 83 distances = self._distance_matrix(query, neighbor_embeddings)
#      84 closest_idx = np.argmin(distances)
#      85 return neighbors[closest_idx]
#
# File ~/Documents/david/pdf-search-llm-rag/hnsw/hnsw_models.py:89, in HNSW._distance_matrix(self, vec, matrix)
#      87 def _distance_matrix(self, vec, matrix):
#      88     # Calculate Euclidean distance in a vectorized manner
# ---> 89     return np.linalg.norm(matrix - vec, axis=1)
#
# File ~/Library/Caches/pypoetry/virtualenvs/pdf-search-llm-rag-mykPbGiu-py3.9/lib/python3.9/site-packages/numpy/linalg/_linalg.py:2760, in norm(x, ord, axis, keepdims)
#    2758 elif ord == -inf:
#    2759     return abs(x).min(axis=axis, keepdims=keepdims)
# -> 2760 elif ord == 0:
#    2761     # Zero norm
#    2762     return (
#    2763         (x != 0)
#    2764         .astype(x.real.dtype)
#    2765         .sum(axis=axis, keepdims=keepdims)
#    2766     )
#    2767 elif ord == 1:
#    2768     # special case for speedup
#
# KeyboardInterrupt:

# %%
all_benchmark_results.sort_values(by='average_recall', ascending=False)
# Out:
#      method  num_embeddings  embedding_dim  average_recall  average_precision  \
# 7   HNSW_V2           10000            738        0.101004           0.101004
# 13  HNSW_V2           10000           1024        0.099996           0.099996
# 1   HNSW_V2           10000            128        0.094812           0.094812
# 15  HNSW_V2           10000           1024        0.073391           0.073391
# 9   HNSW_V2           10000            738        0.071457           0.071457
# 3   HNSW_V2           10000            128        0.070461           0.070461
# 25  HNSW_V2          100000            738        0.069033           0.069033
# 19  HNSW_V2          100000            128        0.057248           0.057248
# 17  HNSW_V2           10000           1024        0.046599           0.046599
# 21  HNSW_V2          100000            128        0.046166           0.046166
# 5   HNSW_V2           10000            128        0.045981           0.045981
# 11  HNSW_V2           10000            738        0.044215           0.044215
# 23  HNSW_V2          100000            128        0.033982           0.033982
# 0   HNSW_V1           10000            128        0.009220           0.009220
# 2   HNSW_V1           10000            128        0.007956           0.007956
# 12  HNSW_V1           10000           1024        0.007516           0.007516
# 6   HNSW_V1           10000            738        0.006630           0.006630
# 14  HNSW_V1           10000           1024        0.006573           0.006573
# 4   HNSW_V1           10000            128        0.006505           0.006505
# 8   HNSW_V1           10000            738        0.005888           0.005888
# 16  HNSW_V1           10000           1024        0.005477           0.005477
# 10  HNSW_V1           10000            738        0.005044           0.005044
# 18  HNSW_V1          100000            128        0.004320           0.004320
# 20  HNSW_V1          100000            128        0.003805           0.003805
# 22  HNSW_V1          100000            128        0.003206           0.003206
# 24  HNSW_V1          100000            738        0.002602           0.002602
#
#     average_mrr     add_time  search_time  knn_exact_search_time
# 7           1.0    24.948915    67.162294               0.875711
# 13          1.0    27.623407    78.783004               1.027910
# 1           1.0    11.748826    38.476377               0.319315
# 15          1.0    29.371940    79.769873               1.119569
# 9           1.0    20.987157    60.905278               0.941233
# 3           1.0    11.844858    36.559242               0.382702
# 25          1.0  2083.485636  9855.708013              51.246814
# 19          1.0  1380.705236  8273.188709              10.143399
# 17          1.0    35.942324    94.451164               1.273007
# 21          1.0  1262.492269  5266.561156               9.304619
# 5           1.0    13.057807    38.390788               0.592515
# 11          1.0    25.223179    73.753915               1.108846
# 23          1.0  1240.837729  6446.189181               9.809806
# 0           1.0     0.681468     1.020932               0.319315
# 2           1.0     0.685793     0.933639               0.382702
# 12          1.0     4.126374     5.114525               1.027910
# 6           1.0     2.589775     2.758092               0.875711
# 14          1.0     3.028666     5.368017               1.119569
# 4           1.0     0.639899     0.929345               0.592515
# 8           1.0     1.857170     3.166031               0.941233
# 16          1.0     5.354798     7.187980               1.273007
# 10          1.0     4.063242     4.921578               1.108846
# 18          1.0    22.392663    26.253883              10.143399
# 20          1.0    15.016373    19.149278               9.304619
# 22          1.0    15.480839    23.537174               9.809806
# 24          1.0    64.937677    72.253464              51.246814
